# %%
import os
import findspark
os.chdir('../')

# %%
import findspark
findspark.init()

# %%
from lib.readfile import ReadFile as rf
from lib.handle_null_values import handle_null_values as null
from lib.datetime_formatting import DatetimeFormatting_v2 as dfmt
from lib.duplication import Duplication as dup

# %%
"""Read the file"""

r= rf()
df= r.read(address="lib/vinod/2009.csv")

# %%
""" Fetch automatically columns containing urd"""
col_list = dup().fetch_columns_containing_url(df)

# %%
""" currently no columns containing url"""
col_list
# Out:
# []

# %%
"""pass the list of urls to remove duplicates url"""
res_df = dup().remove_duplicate_urls(df,col_list,base_url='')
res_df.limit(100).toPandas()

### currently there are no url columns
# Out:
#          id  ml_number mls_created_date     mls_updated_date status  \
# 0   1702541   29104591       2009-07-21  2017-01-12 13:58:56   Sold
# 1   1719255   29001554       2009-01-02                 NULL   Sold
# 2   1719257   29002134       2009-01-01  2010-01-12 16:09:00   Sold
# 3   1719261   29004320       2009-01-07  2010-04-22 12:21:43   Sold
# 4   1719263   29006588       2009-01-12  2010-02-12 13:55:36   Sold
# ..      ...        ...              ...                  ...    ...
# 95  1719455   29077013       2009-05-31  2010-01-06 16:35:00   Sold
# 96  1719457   29078016       2009-05-29  2010-04-24 12:35:37   Sold
# 97  1719459   29077872       2009-06-02  2010-01-28 20:15:38   Sold
# 98  1719461   29077860       2009-06-01  2010-01-21 08:55:00   Sold
# 99  1719463   29079113       2009-06-03  2010-04-26 15:05:39   Sold
#
#    status_before_removed property_type  list_date  sold_date  list_price  ...  \
# 0                   NULL   Residential 2009-07-21 2010-06-28    215500.0  ...
# 1                   NULL   Condominium 2009-01-02 2010-04-30    150000.0  ...
# 2                   NULL   Condominium 2009-01-01 2010-01-08    435000.0  ...
# 3                   NULL   Condominium 2009-01-07 2010-04-21    370500.0  ...
# 4                   NULL   Condominium 2009-01-12 2009-12-04    429000.0  ...
# ..                   ...           ...        ...        ...         ...  ...
# 95                  NULL   Condominium 2009-05-31 2010-01-06    349400.0  ...
# 96                  NULL   Condominium 2009-05-29 2010-04-23    230000.0  ...
# 97                  NULL   Condominium 2009-06-02 2010-01-28    195000.0  ...
# 98                  NULL   Condominium 2009-06-01 2010-01-19    165000.0  ...
# 99                  NULL   Condominium 2009-06-03 2010-02-12    269950.0  ...
#
#      matrix_modified_dt     last_upload_date is_comp was_flip  \
# 0   2018-03-12 08:00:23  0000-00-00 00:00:00       0        N
# 1   2018-07-03 06:23:50  0000-00-00 00:00:00    NULL        N
# 2   2018-07-03 06:23:50  0000-00-00 00:00:00       0        N
# 3   2018-07-03 06:23:50  0000-00-00 00:00:00       0        N
# 4   2018-07-03 06:23:50  0000-00-00 00:00:00       0        N
# ..                  ...                  ...     ...      ...
# 95  2018-07-03 06:23:50  0000-00-00 00:00:00       0        N
# 96  2018-07-03 06:23:50  0000-00-00 00:00:00       0        N
# 97  2018-07-03 06:23:50  0000-00-00 00:00:00       0        N
# 98  2018-07-05 13:36:04  0000-00-00 00:00:00       0        N
# 99  2018-07-03 06:23:50  0000-00-00 00:00:00       0        N
#
#    previous_sale_ml_number previous_sale_date  previous_sale_price  \
# 0                        0         0000-00-00                 0.00
# 1                        0         0000-00-00                 0.00
# 2                 29075344         2009-11-16                 0.00
# 3                        0         0000-00-00                 0.00
# 4                 29045634         2009-10-19                 0.00
# ..                     ...                ...                  ...
# 95                       0         0000-00-00                 0.00
# 96                29076300         2010-04-23                 0.00
# 97                       0         0000-00-00                 0.00
# 98                       0         0000-00-00                 0.00
# 99                       0         0000-00-00                 0.00
#
#     fetched_for_cma  cron_id  record_status
# 0                 N   243655              N
# 1                 N     NULL              A
# 2                 N    84248              A
# 3                 N    84248              A
# 4                 N    84248              A
# ..              ...      ...            ...
# 95                N    84248              A
# 96                N    84248              A
# 97                N    84248              A
# 98                N    84248              A
# 99                N    84248              A
#
# [100 rows x 395 columns]

# %%
""" Remove all the columns which contains nan exceeding the threshold """
# threshold is considered as percent
print("total columns",len(df.columns))
res_df = dup().remove_columns_containing_all_nan_values(df,threshold=75)
print("only valid columns",len(res_df.columns))
print("columns contains null more than 75pct",len(df.columns)-len(res_df.columns))
# Out:
# total columns 395
# only valid columns 350
# columns contains null more than 75pct 45

# %%
""" remove columns which contains same value in all rows """
print("total columns",len(df.columns))
res_df = dup().remove_columns_contains_same_value(df)
print("only valid columns",len(res_df.columns))
# Out:
# total columns 395
# only valid columns 347

# %%
res_df.columns
# Out:
# ['id',
#  'ml_number',
#  'mls_created_date',
#  'mls_updated_date',
#  'property_type',
#  'list_date',
#  'sold_date',
#  'list_price',
#  'sold_price',
#  'address',
#  'city_name',
#  'county',
#  'zip_code',
#  'area',
#  'latitude',
#  'longitude',
#  'bedroom_count',
#  'bathroom_count',
#  'square_foot',
#  'lot_size',
#  'showing_information',
#  'public_comments',
#  'remarks',
#  'style',
#  'view',
#  'levels',
#  'garage',
#  'pool',
#  'heating_cooling',
#  'elementary_school',
#  'junior_high_school',
#  'high_school',
#  'interior',
#  'exterior',
#  'other_features',
#  'cross_street',
#  'unit_number',
#  'agent_comments',
#  'annual_taxes',
#  'apn',
#  'architecture',
#  'builder',
#  'building_condition',
#  'building_information',
#  'bus_line_nearby',
#  'cdom',
#  'fireplaces_count',
#  'floor_covering',
#  'foundation',
#  'leased_equipment',
#  'legal_description',
#  'listing_agent_id',
#  'colisting_agent_id',
#  'colisting_office_id',
#  'parcel_number',
#  'lot_details',
#  'lot_measurement',
#  'lot_number',
#  'tax_year',
#  'covered_parking',
#  'unfinished_sq_foot',
#  'virtual_tour_url',
#  'water',
#  'water_company',
#  'waterfront_footage',
#  'water_heater_location',
#  'water_heater_type',
#  'year_built',
#  'bank_owned',
#  'third_party_approval',
#  'association_fees',
#  'building_complex',
#  'topography',
#  'manufacturer',
#  'occupant_type',
#  'original_price',
#  'phone_to_show',
#  'possession',
#  'power_company',
#  'preliminary_title_ordered',
#  'roof',
#  'school_district',
#  'sewer_company',
#  'site_features',
#  'community_name',
#  'selling_agent_number',
#  'monthly_rent',
#  'community_features',
#  'zoning_jurisdiction',
#  'zoning_code',
#  'pictures',
#  'walk_score',
#  'transit_score',
#  'transit_score_summary',
#  'bike_score',
#  'bike_score_msg',
#  'walk_score_status',
#  'bike_score_status',
#  'transit_score_status',
#  'effective_year_built_source',
#  'lot_size_source',
#  'map_book',
#  'show_map_link_to_public',
#  'prohibit_blogging',
#  'auction',
#  'form_17',
#  'terms',
#  'sewer',
#  'leased_items',
#  'net_operating_income',
#  'gross_adjusted_income',
#  'gross_scheduled_income',
#  'total_monthly_income',
#  'insurance_expenses',
#  'gross_rent_multiplier',
#  'total_expenses',
#  'vacancy_rate',
#  'cap_rate_noi_div_lp',
#  'agent_name',
#  'energy_source',
#  'office_name',
#  'office_phone',
#  'transit_msg',
#  'walk_score_msg',
#  'property_features',
#  'type_fireplace',
#  'list_date_received',
#  'number_employees',
#  'ef_year_built',
#  'year_established',
#  'years_current_owner_business',
#  'year_value_assessed',
#  'multi_family_data',
#  'units_in_complex',
#  'stories_in_building',
#  'units_in_building',
#  'net_proceeds',
#  'occupancy_percentage',
#  'other_expenses',
#  'remodeled',
#  'real_estate_value',
#  'first_refusal',
#  'restrictions',
#  'special_assessment_amount',
#  'section_township',
#  'septic_system',
#  'sib',
#  'special_assessment',
#  'total_assessed_value',
#  'annual_expenses',
#  'total_monthly_rent',
#  'total_square_feet_rented',
#  'total_number_parking_spaces',
#  'turn_over',
#  'unit_floor_number',
#  'uncovered_spaces',
#  'included_rent',
#  'improved_assessed_value',
#  'land_assessed_value',
#  'water_jurisdiction',
#  'water_sewer_garbage',
#  'zoning_remarks',
#  'offers',
#  'affiliations',
#  'fha_va',
#  'additional_finished_rooms',
#  'age_restrictions',
#  'power_service_amps',
#  'foundation_anc',
#  'appliance_hookups',
#  'appliances_provided',
#  'association_contact',
#  'assessment_fees',
#  'number_available_pads',
#  'boundary_survey',
#  'bedrooms',
#  'boarding_income',
#  'barn_size',
#  'barn_type',
#  'cap_rate',
#  'ceiling_height',
#  'co_op_y_n',
#  'crop_income',
#  'column_spacing',
#  'cats_dogs',
#  'depth_lot',
#  'documents_provided',
#  'electricity',
#  'elevation',
#  'electrical_expenses',
#  'environment_survey',
#  'equity',
#  'equipment_included',
#  'equipment',
#  'equipment_value',
#  'easements',
#  'expansion_area',
#  'total_expenses_exp',
#  'free_clear',
#  'fence',
#  'financing',
#  'franchise',
#  'farm_type',
#  'furnished',
#  'gas_available',
#  'major_type_business',
#  'annual_gross_sales',
#  'number_garage_spaces',
#  'goodwill_value',
#  'general_zoning_classification',
#  'heating_expenses',
#  'home_owner_dues_include',
#  'hours_operation',
#  'improvements',
#  'move_in_funds_required',
#  'inventory_value',
#  'irrigation_source',
#  'irrigation_type',
#  'loading',
#  'leased_equipment_leq',
#  'licenses',
#  'manager_contact_information',
#  'labor_industries_inspected',
#  'location',
#  'lease_income',
#  'livestock_type',
#  'business_name',
#  'number_assigned_spaces',
#  'number_carport_spaces',
#  'other_rooms',
#  'outbuildings',
#  'ownership',
#  'pad_ready',
#  'park_approval_sale',
#  'total_covered_parking',
#  'parking_type',
#  'parking_space_number',
#  'total_uncovered_parking',
#  'park_name',
#  'parlor_size',
#  'space_rent_includes',
#  'real_property',
#  'space_rent_per_month',
#  'septic_system_type',
#  'storage_size',
#  'storage_number',
#  'storage_location',
#  'storage',
#  'number_access_stairs',
#  'type_property',
#  'window_covering',
#  'week_assignment',
#  'zip_plus_4',
#  'community_number',
#  'map_page',
#  'x_coordinate',
#  'y_coordinate',
#  'selling_office_number',
#  'publish_to_internet',
#  'show_address_to_public',
#  'selling_co_agent_number',
#  'selling_co_office_number',
#  'quarter_bathrooms',
#  'street_number_modifier',
#  'co_office',
#  'approved_accessory_dwelling',
#  'bedrooms_lower',
#  'bedrooms_main',
#  'bedrooms_upper',
#  'block',
#  'bonus_room_location',
#  'den_or_office',
#  'dining_room_location',
#  'extra_finished_room_location',
#  'entrance_level',
#  'family_room_location',
#  'full_baths_garage',
#  'full_baths_lower',
#  'full_baths_main',
#  'full_baths_total',
#  'full_baths_upper',
#  'fireplaces_lower',
#  'fireplaces_main',
#  'fireplaces_upper',
#  'half_baths_garage',
#  'half_baths_lower',
#  'half_baths_main',
#  'half_baths_upper',
#  'kitchen_eating_space_location',
#  'kitchen_location',
#  'living_room_location',
#  'master_bedroom_level',
#  'manufactured_home_model_name',
#  'manufactured_home_serial_number',
#  'new_construction_nc',
#  'project',
#  'three_quarter_baths_total',
#  'rec_room_location',
#  'approved_bedrooms',
#  'square_footage_finished',
#  'square_footage_source',
#  'senior_exemption',
#  'three_quarter_baths_garage',
#  'three_quarter_baths_lower',
#  'three_quarter_main',
#  'three_quarter_upper',
#  'utility_room_location',
#  'basement',
#  'waterfront',
#  'bus_route_number',
#  'environmental_cert',
#  'allow_automated_valuation',
#  'built_green_certification_rating',
#  'hers_index',
#  'eps_enery',
#  'new_construction',
#  'offers_review_date',
#  'unit_features',
#  'view_comments',
#  'acreage_comments',
#  'barn_outbuilding_comments',
#  'common_features',
#  'minimum_rental_terms',
#  'park_amenities',
#  'survey',
#  'terms_remarks',
#  'actual_images',
#  'downloading_inprogress',
#  'yoy_processed_date',
#  'contingent_date',
#  'inactive_date',
#  'status_change_date',
#  'pending_date',
#  'available_date',
#  'created_date',
#  'removed_date',
#  'processed_matrix_date',
#  'matrix_modified_dt',
#  'last_upload_date',
#  'is_comp',
#  'was_flip',
#  'previous_sale_ml_number',
#  'previous_sale_date',
#  'previous_sale_price',
#  'fetched_for_cma',
#  'cron_id',
#  'record_status']

# %%
""" converting file into chunks
    every chunk contains 100 rows
    currenlty only lenght of each chunk is printed
    but we can call any function inside the functtion
"""
dup().converting_file_into_chunks(df,100)
# Out:
# 99
# ############
# 100
# ############
# 100
# ############
# 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-d80663680235> in <module>
#       2     every chunk contains 100 rows
#       3 """
# ----> 4 dup().converting_file_into_chunks(df,100)
#
# D:\Projects\data-science\open source projects\mltrons_auto_clean\lib\duplication.py in converting_file_into_chunks(self, df, chunk_size)
#     145             print(chunk.count())
#     146             if chunk.count() != 0:
# --> 147                 pd_df = chunk.toPandas()
#     148
#     149                 ### you can do what ever you want to with the pandas ddataframe
#
# C:\spark\python\pyspark\sql\dataframe.py in toPandas(self)
#    2141
#    2142         # Below is toPandas without Arrow optimization.
# -> 2143         pdf = pd.DataFrame.from_records(self.collect(), columns=self.columns)
#    2144
#    2145         dtype = {}
#
# C:\spark\python\pyspark\sql\dataframe.py in collect(self)
#     532         """
#     533         with SCCallSiteSync(self._sc) as css:
# --> 534             sock_info = self._jdf.collectToPython()
#     535         return list(_load_from_socket(sock_info, BatchedSerializer(PickleSerializer())))
#     536
#
# C:\spark\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in __call__(self, *args)
#    1253             proto.END_COMMAND_PART
#    1254
# -> 1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
#    1257             answer, self.gateway_client, self.target_id, self.name)
#
# C:\spark\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in send_command(self, command, retry, binary)
#     983         connection = self._get_connection()
#     984         try:
# --> 985             response = connection.send_command(command)
#     986             if binary:
#     987                 return response, self._create_connection_guard(connection)
#
# C:\spark\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in send_command(self, command)
#    1150
#    1151         try:
# -> 1152             answer = smart_decode(self.stream.readline()[:-1])
#    1153             logger.debug("Answer received: {0}".format(answer))
#    1154             if answer.startswith(proto.RETURN_MESSAGE):
#
# c:\users\tawab\anaconda3\envs\mltrons_auto_clean\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
""" fetch columns containing date time"""
date_list = dfmt().fetch_columns_containing_datetime(df)

# %%
date_list
# Out:
# ['mls_created_date',
#  'mls_updated_date',
#  'list_date',
#  'sold_date',
#  'list_date_received',
#  'offers_review_date',
#  'yoy_processed_date',
#  'contingent_date',
#  'inactive_date',
#  'status_change_date',
#  'pending_date',
#  'available_date',
#  'created_date',
#  'processed_matrix_date',
#  'matrix_modified_dt',
#  'last_upload_date',
#  'previous_sale_date']

# %%
""" converting all datetime format in a standard format """
res_df=dfmt().date_cleaning(df[date_list], date_list)
res_df.limit(100).toPandas()
# Out:
#    mls_created_date     mls_updated_date  list_date  sold_date  \
# 0        2009-07-21  2017-01-12 13:58:56 2009-07-21 2010-06-28
# 1        2009-01-02                 NULL 2009-01-02 2010-04-30
# 2        2009-01-01  2010-01-12 16:09:00 2009-01-01 2010-01-08
# 3        2009-01-07  2010-04-22 12:21:43 2009-01-07 2010-04-21
# 4        2009-01-12  2010-02-12 13:55:36 2009-01-12 2009-12-04
# ..              ...                  ...        ...        ...
# 95       2009-05-31  2010-01-06 16:35:00 2009-05-31 2010-01-06
# 96       2009-05-29  2010-04-24 12:35:37 2009-05-29 2010-04-23
# 97       2009-06-02  2010-01-28 20:15:38 2009-06-02 2010-01-28
# 98       2009-06-01  2010-01-21 08:55:00 2009-06-01 2010-01-19
# 99       2009-06-03  2010-04-26 15:05:39 2009-06-03 2010-02-12
#
#      list_date_received   offers_review_date   yoy_processed_date  \
# 0   2009-07-21 00:00:00  0000-00-00 00:00:00  0000-00-00 00:00:00
# 1                  NULL                 NULL                 NULL
# 2                  NULL                 NULL  0000-00-00 00:00:00
# 3                  NULL                 NULL  0000-00-00 00:00:00
# 4                  NULL                 NULL  0000-00-00 00:00:00
# ..                  ...                  ...                  ...
# 95                 NULL                 NULL  0000-00-00 00:00:00
# 96                 NULL                 NULL  0000-00-00 00:00:00
# 97                 NULL                 NULL  0000-00-00 00:00:00
# 98                 NULL                 NULL  0000-00-00 00:00:00
# 99                 NULL                 NULL  0000-00-00 00:00:00
#
#         contingent_date        inactive_date   status_change_date  ...  \
# 0   1800-01-01 00:00:00  1800-01-01 00:00:00  2010-07-23 14:56:41  ...
# 1   1800-01-01 00:00:00  1800-01-01 00:00:00  2010-04-30 00:00:00  ...
# 2   1800-01-01 00:00:00  1800-01-01 00:00:00  2010-01-12 00:00:00  ...
# 3   1800-01-01 00:00:00  1800-01-01 00:00:00  2010-04-21 00:00:00  ...
# 4   1800-01-01 00:00:00  1800-01-01 00:00:00  2010-02-12 00:00:00  ...
# ..                  ...                  ...                  ...  ...
# 95  1800-01-01 00:00:00  1800-01-01 00:00:00  2010-01-06 00:00:00  ...
# 96  1800-01-01 00:00:00  1800-01-01 00:00:00  2010-04-24 00:00:00  ...
# 97  1800-01-01 00:00:00  1800-01-01 00:00:00  2010-01-28 00:00:00  ...
# 98  1800-01-01 00:00:00  1800-01-01 00:00:00  2010-01-21 00:00:00  ...
# 99  1800-01-01 00:00:00  1800-01-01 00:00:00  2010-04-26 00:00:00  ...
#
#     contingent_date_new    inactive_date_new status_change_date_new  \
# 0   1800-01-01 00:00:00  1800-01-01 00:00:00    2010-07-23 14:56:41
# 1   1800-01-01 00:00:00  1800-01-01 00:00:00    2010-04-30 00:00:00
# 2   1800-01-01 00:00:00  1800-01-01 00:00:00    2010-01-12 00:00:00
# 3   1800-01-01 00:00:00  1800-01-01 00:00:00    2010-04-21 00:00:00
# 4   1800-01-01 00:00:00  1800-01-01 00:00:00    2010-02-12 00:00:00
# ..                  ...                  ...                    ...
# 95  1800-01-01 00:00:00  1800-01-01 00:00:00    2010-01-06 00:00:00
# 96  1800-01-01 00:00:00  1800-01-01 00:00:00    2010-04-24 00:00:00
# 97  1800-01-01 00:00:00  1800-01-01 00:00:00    2010-01-28 00:00:00
# 98  1800-01-01 00:00:00  1800-01-01 00:00:00    2010-01-21 00:00:00
# 99  1800-01-01 00:00:00  1800-01-01 00:00:00    2010-04-26 00:00:00
#
#        pending_date_new   available_date_new     created_date_new  \
# 0   2010-01-20 00:00:00  1800-01-01 00:00:00  2018-03-12 08:00:23
# 1   2010-04-16 00:00:00                 NULL  2017-04-10 13:47:42
# 2   2009-11-20 00:00:00  1800-01-01 00:00:00  2017-08-06 10:00:59
# 3   2010-03-05 00:00:00  1800-01-01 00:00:00  2017-08-06 10:01:30
# 4   2009-09-24 00:00:00  1800-01-01 00:00:00  2017-08-06 10:01:48
# ..                  ...                  ...                  ...
# 95  2009-10-26 00:00:00  1800-01-01 00:00:00  2017-08-06 10:01:36
# 96  2009-09-16 00:00:00  1800-01-01 00:00:00  2017-08-06 10:01:25
# 97  2009-12-23 00:00:00  1800-01-01 00:00:00  2017-08-06 10:01:26
# 98  2009-12-04 00:00:00  1800-01-01 00:00:00  2017-08-06 10:02:17
# 99  2009-09-04 00:00:00  1800-01-01 00:00:00  2017-08-06 10:00:53
#
#    processed_matrix_date_new matrix_modified_dt_new last_upload_date_new  \
# 0        0000-00-00 00:00:00    2018-03-12 08:00:23  0000-00-00 00:00:00
# 1        0000-00-00 00:00:00    2018-07-03 06:23:50  0000-00-00 00:00:00
# 2        0000-00-00 00:00:00    2018-07-03 06:23:50  0000-00-00 00:00:00
# 3        0000-00-00 00:00:00    2018-07-03 06:23:50  0000-00-00 00:00:00
# 4        0000-00-00 00:00:00    2018-07-03 06:23:50  0000-00-00 00:00:00
# ..                       ...                    ...                  ...
# 95       0000-00-00 00:00:00    2018-07-03 06:23:50  0000-00-00 00:00:00
# 96       0000-00-00 00:00:00    2018-07-03 06:23:50  0000-00-00 00:00:00
# 97       0000-00-00 00:00:00    2018-07-03 06:23:50  0000-00-00 00:00:00
# 98       0000-00-00 00:00:00    2018-07-05 13:36:04  0000-00-00 00:00:00
# 99       0000-00-00 00:00:00    2018-07-03 06:23:50  0000-00-00 00:00:00
#
#    previous_sale_date_new
# 0              0000-00-00
# 1              0000-00-00
# 2     2009-11-16 00:00:00
# 3              0000-00-00
# 4     2009-10-19 00:00:00
# ..                    ...
# 95             0000-00-00
# 96    2010-04-23 00:00:00
# 97             0000-00-00
# 98             0000-00-00
# 99             0000-00-00
#
# [100 rows x 34 columns]

# %%
# Out:
#    mls_created_date     mls_updated_date mls_created_date_new  \
# 0        2009-07-21  2017-01-12 13:58:56  2009-07-21 00:00:00
# 1        2009-01-02                 NULL  2009-01-02 00:00:00
# 2        2009-01-01  2010-01-12 16:09:00  2009-01-01 00:00:00
# 3        2009-01-07  2010-04-22 12:21:43  2009-01-07 00:00:00
# 4        2009-01-12  2010-02-12 13:55:36  2009-01-12 00:00:00
# ..              ...                  ...                  ...
# 95       2009-05-31  2010-01-06 16:35:00  2009-05-31 00:00:00
# 96       2009-05-29  2010-04-24 12:35:37  2009-05-29 00:00:00
# 97       2009-06-02  2010-01-28 20:15:38  2009-06-02 00:00:00
# 98       2009-06-01  2010-01-21 08:55:00  2009-06-01 00:00:00
# 99       2009-06-03  2010-04-26 15:05:39  2009-06-03 00:00:00
#
#    mls_updated_date_new
# 0   2017-01-12 13:58:56
# 1                  NULL
# 2   2010-01-12 16:09:00
# 3   2010-04-22 12:21:43
# 4   2010-02-12 13:55:36
# ..                  ...
# 95  2010-01-06 16:35:00
# 96  2010-04-24 12:35:37
# 97  2010-01-28 20:15:38
# 98  2010-01-21 08:55:00
# 99  2010-04-26 15:05:39
#
# [100 rows x 4 columns]
